# %%
import os
import pandas as pd
import re
import psycopg2

# %%
CSV_DIRECTORY = 'E:/EcoThrift - Preprocessing/raw/'

# Developement
DB_HOST = 'localhost'
DB_NAME = 'EcoThrift - Developement'
DB_USER = 'postgres'
DB_PASSWORD = 'password'

# Production
'''
DB_HOST = 'ec2-34-237-167-13.compute-1.amazonaws.com'
DB_NAME = 'd4op06smk6i192'
DB_USER = 'u4lpm5bu1q2uan'
DB_PASSWORD = 'p61f5ea94216c5aba0b43b2cc69c05641f680424e972b7982df23acc4a7a43a16'
'''

csv_files = [file for file in os.listdir(CSV_DIRECTORY) if file.endswith('.csv')]
# Out:
# ['cstATL-4865135.csv',
#  'cstMON-4922544.csv',
#  'cstTRA-4915346.csv',
#  'cstTRA-4915347.csv']

# %%
processed_files = []
unprocessed_files = []
templates = {}

for file in csv_files:
    try:
        df = pd.read_csv(os.path.join(CSV_DIRECTORY, file))
        # Process the DataFrame
        processed_files.append(file)
    except Exception as e:
        print(f"Error processing {file}: {str(e)}")
        unprocessed_files.append(file)

# %%
processed_dfs = {}
for file in processed_files:
    df = pd.read_csv(os.path.join(CSV_DIRECTORY, file))
    processed_dfs[file] = df
# Out:
# {'cstATL-4865135.csv':       Lot #   Item #  Dept. Code        Department           Item Description  \
#  0   4865135   888584          28     TOYS/SEASONAL   DOWDLE PUZZLE ASSORTMENT
#  1   4865135  1748925          24  MAJOR APPLIANCES   WASHBURN ACOUSTIC GUITAR
#  2   4865135  1756655          24  MAJOR APPLIANCES     ROLAND E-X10 KEYBOARD/
#  3   4865135  1601380          28     TOYS/SEASONAL         ASCEND AERONAUTICS
#  4   4865135  1601351          28     TOYS/SEASONAL   KIDKRAFT BEAT BOARD GAME
#  ..      ...      ...         ...               ...                        ...
#  57  4865135  1742790          28     TOYS/SEASONAL  DINO HAULER W/4 DINOS GRY
#  58  4865135  1601332          28     TOYS/SEASONAL  CLASSIC CARD GAMES BUNDLE
#  59  4865135  1540571          26    SPORTING GOODS  TEKK MONSTER JAM MINIHOOP
#  60  4865135  1598444          28     TOYS/SEASONAL     SQUISHMALLOW ORNAMENTS
#  61  4865135  1513333          37              NEXT  CX - THE LEARNING JOURNEY
#
#      Qty  Unit Retail  Ext. Retail                      Brand Category Code  \
#  0   207         9.99      2067.93  AMERICANA ART ENTERPRISES           AHP
#  1     9       189.99      1709.91     JAM INDUSTRIES USA LLC           FGA
#  2     6       199.99      1199.94      ROLAND CORPORATION US           FKA
#  3    12        69.99       839.88         AMAX GROUP USA LLC           AHE
#  4    16        49.99       799.84               KIDKRAFT INC           AHE
#  ..  ...          ...          ...                        ...           ...
#  57    1        24.99        24.99             KID GALAXY INC           ACF
#  58    1        19.99        19.99  MATTEL BRANDS DIVISION OF           AHG
#  59    1        18.99        18.99          TEKK ATHLETIC INC           HBE
#  60    1        17.49        17.49               JAZWARES LLC           AAS
#  61    1         1.00         1.00  THE LEARNING JOURNEY INTE           SNI
#
#                 Category
#  0                  Toys
#  1   Musical Instruments
#  2   Musical Instruments
#  3                  Toys
#  4                  Toys
#  ..                  ...
#  57                 Toys
#  58                 Toys
#  59   Athletic Equipment
#  60                 Toys
#  61                  NaN
#
#  [62 rows x 11 columns],
#  'cstMON-4922544.csv':      Lot #   Item #  Dept. Code            Department       Item Description  \
#  0  4922544  1736860          20  HEALTH & BEAUTY AIDS  POPMASK HAIR SET P336
#  1  4922544  1715739          20  HEALTH & BEAUTY AIDS              WET BRUSH
#  2  4922544  1731309          20  HEALTH & BEAUTY AIDS  CRAYOLA NEON BATH SET
#
#     Qty  Unit Retail  Ext. Retail                 Brand Category Code  \
#  0  784        23.99     18808.16           POPBAND INC           HHC
#  1  766        19.99     15312.34  J AND D BRUSH CO LLC           HHC
#  2  144        19.99      2878.56    CENTRIC BEAUTY LLC           AJW
#
#             Category
#  0         Hair Care
#  1         Hair Care
#  2  Hygiene Products  ,
#  'cstTRA-4915346.csv':       Lot #   Item #  Dept. Code Department           Item Description  Qty  \
#  0   4915346  1721708          35    JEWELRY         98B405 BULOVA MENS    2
#  1   4915346  1769448          35    JEWELRY  FC-296SW5B4 MNS FREDERIQE    1
#  2   4915346  1769454          35    JEWELRY  FC-303GR5B6B MNS FREDERIQ    1
#  3   4915346  1748118          35    JEWELRY          98R298 BULOVA LDS    2
#  4   4915346  1748176          35    JEWELRY     CA4500-08X CITIZEN MNS    3
#  5   4915346  1748287          35    JEWELRY   12/7740WTST LDS A. KLEIN    4
#  6   4915346  1184301          35    JEWELRY  8160-SR1-20001 MNS RMNDWL    1
#  7   4915346  1686749          35    JEWELRY  T0352106605100 TISSOT LDS    1
#  8   4915346  1693845          35    JEWELRY        98B400 BULOVA MEN'S    2
#  9   4915346  1735441          35    JEWELRY    BN0225-04L CITIZEN MENS    1
#  10  4915346  1748093          35    JEWELRY          97B217 BULOVA MNS    1
#  11  4915346  1693856          35    JEWELRY        98D182 BULOVA MEN'S    1
#  12  4915346  1735444          35    JEWELRY    AW1248-80E CITIZEN MENS    1
#  13  4915346  1593041          35    JEWELRY   98B365 BULOVA MENS BLACK    1
#  14  4915346  1593562          35    JEWELRY  98L297 BULOVA LDS TWOTONE    1
#  15  4915346  1641028          35    JEWELRY   AW1428-53X CITIZEN MEN'S    1
#  16  4915346  1689013          35    JEWELRY       TW6Z2810ZV TIMEX MNS    1
#  17  4915346  1735951          35    JEWELRY      TW2V38000VQ TIMEX MNS    1
#  18  4915346  1722359          35    JEWELRY     12/2353MPSV ANNE KLEIN    2
#  19  4915346  1648331          35    JEWELRY   TW2T22800ZV TIMEX MARLIN    1
#  20  4915346  1735950          35    JEWELRY      TW2V03900JR TIMEX MNS    1
#  21  4915346  1648220          35    JEWELRY  TW2U82600VQ TIMEX WTRBURY    1
#  22  4915346  1613683          35    JEWELRY   25864 INVICTA BOLT MEN'S    1
#  23  4915346  1637960          35    JEWELRY     12/2341MPRT ANNE KLEIN    1
#  24  4915346  1708838          35    JEWELRY       44704 INVICTA MNS SS    1
#  15  4915347  1647930          35    JEWELRY  SUP453 SEIKO LADIES WATCH    1
#  16  4915347  1179454          35    JEWELRY  EM0454-52E LDS CITZIN ECO    1
#  17  4915347  1644932          35    JEWELRY    37035 INVICTA BOLT 60MM    1
#  18  4915347  1689013          35    JEWELRY       TW6Z2810ZV TIMEX MNS    1
#  19  4915347  1748176          35    JEWELRY     CA4500-08X CITIZEN MNS    1
#  20  4915347  1613683          35    JEWELRY   25864 INVICTA BOLT MEN'S    2
#  21  4915347  1748294          35    JEWELRY   12/7742MPGB LDS A. KLEIN    2
#  22  4915347   701035          35    JEWELRY         RTV CENTER DEPT 35    1
#  23  4915347   710464          35    JEWELRY   #12/2080SVGB LDS A.KLEIN    1
#  24  4915347  1644918          35    JEWELRY    36362 INVICTA PRO DIVER    1
#  25  4915347  1318346          35    JEWELRY     12/2309SVSV ANNE KLEIN    1
#
#      Unit Retail  Ext. Retail                     Brand Category Code Category
#  0        399.99       799.98  CITIZEN WATCH COMPANY OF           BFF  Watches
#  1        549.99       549.99  CITIZEN WATCH COMPANY OF           BFH  Watches
#  2        499.99       499.99     NATIONAL DISTRIBUTORS           BES  Watches
#  3        149.99       449.97  PRECISION WATCH CO INC A           BCL  Watches
#  4        179.99       359.98       TIMEX GROUP USA INC           BFL  Watches
#  5         89.99       359.96  PRECISION WATCH CO INC A           BCL  Watches
#  6        329.99       329.99  CITIZEN WATCH COMPANY OF           BFH  Watches
#  7        299.99       299.99   KRONOS DISTRIBUTION LLC           TFA  Jewelry
#  8        149.99       299.98       TIMEX GROUP USA INC           BFL  Watches
#  9        279.99       279.99  CITIZEN WATCH COMPANY OF           BEH  Watches
#  10       279.99       279.99  CITIZEN WATCH COMPANY OF           BFF  Watches
#  11       269.99       269.99  CITIZEN WATCH COMPANY OF           BFH  Watches
#  12        89.99       269.97  INVICTA WATCH COMPANY OF           BEG  Watches
#  13       249.99       249.99  CITIZEN WATCH COMPANY OF           BFH  Watches
#  14       249.99       249.99  CITIZEN WATCH COMPANY OF           BFF  Watches
#  15       229.99       229.99     SEIKO CORP OF AMERICA           BEI  Watches
#  16       199.99       199.99  CITIZEN WATCH COMPANY OF           BEF  Watches
#  17       199.99       199.99  INVICTA WATCH COMPANY OF           BFG  Watches
#  18       199.99       199.99       TIMEX GROUP USA INC           BFL  Watches
#  19       199.99       199.99  CITIZEN WATCH COMPANY OF           BFF  Watches
#  20        99.99       199.98  INVICTA WATCH COMPANY OF           BFG  Watches
#  21        99.99       199.98  PRECISION WATCH CO INC A           BCL  Watches
#  22       130.00       130.00         COSTCO RTV CENTER       #ERROR!      NaN
#  23        99.99        99.99  PRECISION WATCH CO INC A           BCL  Watches
#  24        99.99        99.99  INVICTA WATCH COMPANY OF           BFG  Watches
#  25        79.99        79.99  PRECISION WATCH CO INC A           BTP  Watches  }

# %%
log = {
    'processed_files': processed_files,
    'unprocessed_files': unprocessed_files
}
# Out:
# {'processed_files': ['cstATL-4865135.csv',
#   'cstMON-4922544.csv',
#   'cstTRA-4915346.csv',
#   'cstTRA-4915347.csv'],
#  'unprocessed_files': []}

# %%
def create_template(file, fields):
    template_key = '_'.join(fields)
    templates[template_key] = fields
